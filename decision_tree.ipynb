# %% [markdown]
# <a href="https://colab.research.google.com/github/Isaac-Guz/IA_IB_AgoDic2024/blob/main/decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Activity**: Decision Tree **Student**: Isaac Jair Guzmán Berumen **ID**: 1917725 **Class**: N4-N6 **Group**:002

# %% [markdown]
# Step 1: Load libraries

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn import tree

# %% [markdown]
# Step 2: Load data

# %%
from sklearn import datasets
cb = datasets.load_breast_cancer()

# %%
X = cb.data
y = cb.target

# %%
cb.target_names
# Out:
# array(['malignant', 'benign'], dtype='<U9')

# %% [markdown]
# Step 3. Data preprocessing.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Step 4. Model selection and training.

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
train_accuracy = clf.score(X_train, y_train)
print(train_accuracy)
# Out:
# 1.0

# %% [markdown]
# Step 5: Model testing

# %%
y_pred = clf.predict(X_test)

# %%
#Predicción 1
print(y_pred[1])
print(y_test[1])
# Out:
# 0
# 0

# %%
#Predicción 2
print(y_pred[20])
print(y_test[20])
# Out:
# 1
# 0

# %%
#Predicción 3
print(y_pred[-1])
print(y_test[-1])
# Out:
# 1
# 1

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("Classification Report:\n", classification_report(y_test, y_pred, target_names=cb.target_names))
# Out:
# Accuracy: 0.9122807017543859
# Classification Report:
#                precision    recall  f1-score   support
#
#    malignant       0.85      0.92      0.89        63
#       benign       0.95      0.91      0.93       108
#
#     accuracy                           0.91       171
#    macro avg       0.90      0.91      0.91       171
# weighted avg       0.92      0.91      0.91       171

# %%
plt.figure(figsize=(20, 15))  # Increase figure size for better resolution
tree.plot_tree(clf, filled=True, feature_names=cb.feature_names, class_names=cb.target_names)
plt.title("Decision Tree for Breast Cancer (Diagnostic)")
plt.savefig("decision_tree.png", dpi=300)  # Increase DPI for better resolution
plt.show()
